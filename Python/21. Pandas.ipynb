# %%
# !pip install pandas

# %%
import pandas as pd

# %%
a = (1,2,3,4,5,6)

b = ["one","two","three","four","five","six"] 

#dtype=int

x = pd.Series(data = b)
x
# Out:
# 0      one
# 1      two
# 2    three
# 3     four
# 4     five
# 5      six
# dtype: object

# %%
y = pd.Series(data = a, index=b, dtype= str)
y
# Out:
# one      1
# two      2
# three    3
# four     4
# five     5
# six      6
# dtype: object

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
y[::-1]
# Out:
# six      6
# five     5
# four     4
# three    3
# two      2
# one      1
# dtype: object

# %%
y[1:3]
# Out:
# two      2
# three    3
# dtype: object

# %%
y[-1]
# Out:
# C:\Users\amitm\AppData\Local\Temp\ipykernel_21728\3767466381.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   y[-1]
# '6'

# %%
population_dict ={'California':38332521,
                 'Texas':26448193,
                 'New York':19651127,
                 'Florida':19562860,
                 'Florida':19662860,
                 'Illinois':12882135,
                 'Illinois':12892135}
population_series = pd.Series(population_dict)
population_series
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19662860
# Illinois      12892135
# dtype: int64

# %%
area_dict = {'California':423967,
            'Texas':695662,
            'New York':141297,
            'Florida':170312,
            'Illinois':149995}
area_series = pd.Series(area_dict) 
area_series
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %%
states = pd.DataFrame({'population':population_series,
                      'area':area_series})
states
# Out:
#             population    area
# California    38332521  423967
# Texas         26448193  695662
# New York      19651127  141297
# Florida       19662860  170312
# Illinois      12892135  149995

# %%
type(states)
# Out:
# pandas.core.frame.DataFrame

# %%
states[1:4]
# Out:
#           population    area
# Texas       26448193  695662
# New York    19651127  141297
# Florida     19662860  170312

# %%
states[::-1]
# Out:
#             population    area
# Illinois      12892135  149995
# Florida       19662860  170312
# New York      19651127  141297
# Texas         26448193  695662
# California    38332521  423967

# %%
states[:-4]
# Out:
#             population    area
# California    38332521  423967

# %%
data = [["A",34,23,56],["B",92,88,76],["C",76," ",25],["D"," ",78,99]]

stu = pd.DataFrame(data, columns=["Name",'Maths','Phy','Chem'],index=[1,2,3,4])
stu
# Out:
#   Name Maths Phy  Chem
# 1    A    34  23    56
# 2    B    92  88    76
# 3    C    76        25
# 4    D        78    99

# %%
type(stu["Phy"])
# Out:
# pandas.core.series.Series

# %%
type(stu["Phy","Chem"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Phy', 'Chem')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 type(stu["Phy","Chem"])
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: ('Phy', 'Chem')

# %%
stu.Phy
# Out:
# 1    23
# 2    88
# 3
# 4    78
# Name: Phy, dtype: object

# %%
stu[["Phy","Chem", "Maths"]]
# Out:
#   Phy  Chem Maths
# 1  23    56    34
# 2  88    76    92
# 3        25    76
# 4  78    99

# %%
stu.replace(" ",0)
# Out:
#   Name  Maths  Phy  Chem
# 1    A     34   23    56
# 2    B     92   88    76
# 3    C     76    0    25
# 4    D      0   78    99

# %%
# Selecting Columns
d = {'Chem' : pd.Series([30, 70, 35,25,26,67,77,67,89], index=["Raj",'Ram', 'Asa', 'Pi','Chi','Ru',"Sita","Ria","Gita"],dtype=int),
     'Math' : pd.Series([18, 26, 35, 40,55,89,79,100], index=["Raj",'Ram', 'Pi', 'Chi', 'Ru',"Sita","Ria","Gita"],dtype=int),
     'Phy' : pd.Series([31, 42, 83,34,80,78], index=["Asa",'Ram', 'Pi', 'Ru',"Sita","Gita"],dtype=int)}



exam = pd.DataFrame(d)
exam1=exam.copy() ## To make copy of your data
exam1
# Out:
#       Chem   Math   Phy
# Asa     35    NaN  31.0
# Chi     26   40.0   NaN
# Gita    89  100.0  78.0
# Pi      25   35.0  83.0
# Raj     30   18.0   NaN
# Ram     70   26.0  42.0
# Ria     67   79.0   NaN
# Ru      67   55.0  34.0
# Sita    77   89.0  80.0

# %%
print ("Adding a new column using the existing columns in DataFrame:")

exam1['Total'] = exam1['Chem']+exam1['Math']+exam1['Phy']
exam1
# Out:
# Adding a new column using the existing columns in DataFrame:
#       Chem   Math   Phy  Total
# Asa     35    NaN  31.0    NaN
# Chi     26   40.0   NaN    NaN
# Gita    89  100.0  78.0  267.0
# Pi      25   35.0  83.0  143.0
# Raj     30   18.0   NaN    NaN
# Ram     70   26.0  42.0  138.0
# Ria     67   79.0   NaN    NaN
# Ru      67   55.0  34.0  156.0
# Sita    77   89.0  80.0  246.0

# %%
exam1.isnull().sum()
# Out:
# Chem     0
# Math     1
# Phy      3
# Total    4
# dtype: int64

# %%
exam1["Avg"] = (exam1["Math"] + exam1["Phy"] + exam1["Chem"])/3
exam1
# Out:
#       Chem   Math   Phy  Total        Avg
# Asa     35    NaN  31.0    NaN        NaN
# Chi     26   40.0   NaN    NaN        NaN
# Gita    89  100.0  78.0  267.0  89.000000
# Pi      25   35.0  83.0  143.0  47.666667
# Raj     30   18.0   NaN    NaN        NaN
# Ram     70   26.0  42.0  138.0  46.000000
# Ria     67   79.0   NaN    NaN        NaN
# Ru      67   55.0  34.0  156.0  52.000000
# Sita    77   89.0  80.0  246.0  82.000000

# %%
a = exam1["Math"].median()
a
# Out:
# 47.5

# %%
exam1["Math"] = exam1["Math"].fillna(a)

# %%
exam1
# Out:
#       Chem   Math   Phy  Total        Avg
# Asa     35   47.5  31.0    NaN        NaN
# Chi     26   40.0   NaN    NaN        NaN
# Gita    89  100.0  78.0  267.0  89.000000
# Pi      25   35.0  83.0  143.0  47.666667
# Raj     30   18.0   NaN    NaN        NaN
# Ram     70   26.0  42.0  138.0  46.000000
# Ria     67   79.0   NaN    NaN        NaN
# Ru      67   55.0  34.0  156.0  52.000000
# Sita    77   89.0  80.0  246.0  82.000000

# %%
b = exam1["Phy"].mean()
b
# Out:
# 58.0

# %%
exam1["Phy"] =exam1["Phy"].fillna(b)

# %%
exam1
# Out:
#       Chem   Math   Phy  Total        Avg
# Asa     35   47.5  31.0    NaN        NaN
# Chi     26   40.0  58.0    NaN        NaN
# Gita    89  100.0  78.0  267.0  89.000000
# Pi      25   35.0  83.0  143.0  47.666667
# Raj     30   18.0  58.0    NaN        NaN
# Ram     70   26.0  42.0  138.0  46.000000
# Ria     67   79.0  58.0    NaN        NaN
# Ru      67   55.0  34.0  156.0  52.000000
# Sita    77   89.0  80.0  246.0  82.000000

# %%
exam1.drop(["Total"], axis=1)
# Out:
#       Chem   Math   Phy        Avg
# Asa     35   47.5  31.0        NaN
# Chi     26   40.0  58.0        NaN
# Gita    89  100.0  78.0  89.000000
# Pi      25   35.0  83.0  47.666667
# Raj     30   18.0  58.0        NaN
# Ram     70   26.0  42.0  46.000000
# Ria     67   79.0  58.0        NaN
# Ru      67   55.0  34.0  52.000000
# Sita    77   89.0  80.0  82.000000

# %%
exam1.drop(["Total"], axis=1, inplace=True)

# %%
exam1
# Out:
#       Chem   Math   Phy        Avg
# Asa     35   47.5  31.0        NaN
# Chi     26   40.0  58.0        NaN
# Gita    89  100.0  78.0  89.000000
# Pi      25   35.0  83.0  47.666667
# Raj     30   18.0  58.0        NaN
# Ram     70   26.0  42.0  46.000000
# Ria     67   79.0  58.0        NaN
# Ru      67   55.0  34.0  52.000000
# Sita    77   89.0  80.0  82.000000

# %%
exam1.drop(["Avg"], axis=1, inplace=True)

# %%
exam1["Total"] = exam1["Chem"] + exam1["Phy"] + exam1["Math"]

# %%
exam1
# Out:
#       Chem   Math   Phy  Total
# Asa     35   47.5  31.0  113.5
# Chi     26   40.0  58.0  124.0
# Gita    89  100.0  78.0  267.0
# Pi      25   35.0  83.0  143.0
# Raj     30   18.0  58.0  106.0
# Ram     70   26.0  42.0  138.0
# Ria     67   79.0  58.0  204.0
# Ru      67   55.0  34.0  156.0
# Sita    77   89.0  80.0  246.0

# %%
df = pd.read_csv("C:\\Users\\amitm\\Downloads\\sales_data_final.csv")

# %%
df.head(10)
# Out:
#           order_id order_date ship_date       ship_mode     customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class   Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class     Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class      Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 5    IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 6     CA-2011-1510   1/2/2011  1/6/2011  Standard Class   Magdelene Morse
# 7    IN-2011-79397   1/3/2011  1/3/2011        Same Day       Kean Nguyen
# 8    ID-2011-80230   1/3/2011  1/9/2011  Standard Class      Ken Lonsdale
# 9     IZ-2011-4680   1/3/2011  1/7/2011  Standard Class  Lindsay Williams
#
#        segment            state      country  market   region  ...  \
# 0     Consumer      Constantine      Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales    Australia    APAC  Oceania  ...
# 2     Consumer         Budapest      Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm       Sweden      EU    North  ...
# 4     Consumer  New South Wales    Australia    APAC  Oceania  ...
# 5     Consumer  New South Wales    Australia    APAC  Oceania  ...
# 6     Consumer          Ontario       Canada  Canada   Canada  ...
# 7    Corporate  New South Wales    Australia    APAC  Oceania  ...
# 8     Consumer         Auckland  New Zealand    APAC  Oceania  ...
# 9    Corporate           Ninawa         Iraq    EMEA     EMEA  ...
#
#           category sub_category                             product_name  \
# 0  Office Supplies      Storage                      Tenex Lockers, Blue
# 1  Office Supplies     Supplies                 Acme Trimmer, High Speed
# 2  Office Supplies      Storage                  Tenex Box, Single Width
# 3  Office Supplies        Paper              Enermax Note Cards, Premium
# 4        Furniture  Furnishings               Eldon Light Bulb, Duo Pack
# 5  Office Supplies        Paper  Eaton Computer Printout Paper, 8.5 x 11
# 6       Technology     Machines                 Okidata Inkjet, Wireless
# 7  Office Supplies   Appliances                  Hoover Microwave, White
# 8       Technology      Copiers              Hewlett Wireless Fax, Laser
# 9        Furniture       Chairs         Novimex Swivel Stool, Set of Two
#
#   sales quantity  discount   profit  shipping_cost  order_priority  year
# 0   408        2       0.0  106.140          35.46          Medium  2011
# 1   120        3       0.1   36.036           9.72          Medium  2011
# 2    66        4       0.0   29.640           8.17            High  2011
# 3    45        3       0.5  -26.055           4.82            High  2011
# 4   114        5       0.1   37.770           4.70          Medium  2011
# 5    55        2       0.1   15.342           1.80          Medium  2011
# 6   314        1       0.0    3.120          24.10          Medium  2011
# 7   276        1       0.1  110.412         125.32        Critical  2011
# 8   912        4       0.4 -319.464         107.10             Low  2011
# 9   667        4       0.0  253.320          81.26            High  2011
#
# [10 rows x 21 columns]

# %%
df.tail(10)
# Out:
#              order_id  order_date ship_date       ship_mode  \
# 51280    TZ-2014-8220  12/31/2014  1/6/2015  Standard Class
# 51281  CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51282    UP-2014-4410  12/31/2014  1/4/2015  Standard Class
# 51283   IN-2014-23754  12/31/2014  1/7/2015  Standard Class
# 51284  MX-2014-108574  12/31/2014  1/4/2015  Standard Class
# 51285  CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286    MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287  MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288  MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289  CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#             customer_name      segment             state        country  \
# 51280  Christine Kargatis  Home Office     Dar Es Salaam       Tanzania
# 51281          Erica Bern    Corporate        California  United States
# 51282        Guy Thornton     Consumer      Zaporizhzhya        Ukraine
# 51283        Kalyca Meade    Corporate         Guangdong          China
# 51284       Julia Barnett  Home Office        Tamaulipas         Mexico
# 51285          Erica Bern    Corporate        California  United States
# 51286           Liz Preis     Consumer  Souss-Massa-Dra        Morocco
# 51287    Charlotte Melton     Consumer           Managua      Nicaragua
# 51288       Tamara Dahlen     Consumer         Chihuahua         Mexico
# 51289       Jill Matthias     Consumer          Colorado  United States
#
#        market      region  ...         category sub_category  \
# 51280  Africa      Africa  ...  Office Supplies       Labels
# 51281      US        West  ...  Office Supplies      Binders
# 51282    EMEA        EMEA  ...  Office Supplies       Labels
# 51283    APAC  North Asia  ...  Office Supplies        Paper
# 51284   LATAM       North  ...  Office Supplies       Labels
# 51285      US        West  ...  Office Supplies      Binders
# 51286  Africa      Africa  ...  Office Supplies      Binders
# 51287   LATAM     Central  ...  Office Supplies       Labels
# 51288   LATAM       North  ...  Office Supplies       Labels
# 51289      US        West  ...  Office Supplies    Fasteners
#
#                                           product_name sales quantity  \
# 51280   Harbour Creations Removable Labels, Adjustable    50        6
# 51281                               GBC Binding covers    21        2
# 51282                 Avery Round Labels, Alphabetical    28        4
# 51283                       Eaton Note Cards, 8.5 x 11    79        3
# 51284         Novimex Legal Exhibit Labels, Adjustable    17        3
# 51285  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14        2
# 51286          Wilson Jones Hole Reinforcements, Clear     4        1
# 51287           Hon Color Coded Labels, 5000 Label Set    26        3
# 51288           Hon Legal Exhibit Labels, Alphabetical     7        1
# 51289                              Bagged Rubber Bands     3        3
#
#        discount   profit  shipping_cost  order_priority  year
# 51280       0.0   6.8400           2.15          Medium  2014
# 51281       0.2   6.4750           2.06          Medium  2014
# 51282       0.0   6.1200           1.70          Medium  2014
# 51283       0.0  25.3800           1.41          Medium  2014
# 51284       0.0   0.6600           1.32          Medium  2014
# 51285       0.2   4.5188           0.89          Medium  2014
# 51286       0.0   0.4200           0.49          Medium  2014
# 51287       0.0  12.3600           0.35          Medium  2014
# 51288       0.0   0.5600           0.20          Medium  2014
# 51289       0.2  -0.6048           0.17          Medium  2014
#
# [10 rows x 21 columns]

# %%
df.sample(5)
# Out:
#              order_id  order_date   ship_date       ship_mode  \
# 37718  MX-2014-108980    5/5/2014   5/12/2014  Standard Class
# 33213  MX-2013-109939  12/20/2013  12/25/2013    Second Class
# 41266    GH-2014-8050   7/21/2014   7/23/2014    Second Class
# 34426    NG-2014-6590   1/24/2014   1/29/2014  Standard Class
# 26040   ID-2013-29662   7/22/2013   7/26/2013  Standard Class
#
#          customer_name    segment       state    country  market   region  \
# 37718   Janet Molinari  Corporate     Managua  Nicaragua   LATAM  Central
# 33213    Melanie Seite   Consumer     Nayarit     Mexico   LATAM    North
# 41266  Alejandro Grove   Consumer    Northern      Ghana  Africa   Africa
# 34426     Dan Campbell   Consumer      Maradi      Niger  Africa   Africa
# 26040    Evan Bailliet   Consumer  Queensland  Australia    APAC  Oceania
#
#        ...         category sub_category                     product_name  \
# 37718  ...        Furniture  Furnishings  Rubbermaid Stacking Tray, Black
# 33213  ...        Furniture       Chairs     Novimex Chairmat, Adjustable
# 41266  ...  Office Supplies      Storage             Fellowes Trays, Blue
# 34426  ...       Technology       Phones      Nokia Smart Phone, Cordless
# 26040  ...       Technology      Copiers   Sharp Personal Copier, Digital
#
#       sales quantity  discount   profit  shipping_cost  order_priority  year
# 37718    17        1       0.0    1.340           1.02          Medium  2014
# 33213   188        6       0.2  -21.264           8.71          Medium  2013
# 41266   574       10       0.0   39.900          34.16            High  2014
# 34426   636        1       0.0  203.550          35.01          Medium  2014
# 26040   431        4       0.1  -33.576          33.21          Medium  2013
#
# [5 rows x 21 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df.order_priority
# Out:
# 0        Medium
# 1        Medium
# 2          High
# 3          High
# 4        Medium
#           ...
# 51285    Medium
# 51286    Medium
# 51287    Medium
# 51288    Medium
# 51289    Medium
# Name: order_priority, Length: 51290, dtype: object

# %%
df.shape
# Out:
# (51290, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
#  17  profit          51290 non-null  float64
#  18  shipping_cost   51290 non-null  float64
#  19  order_priority  51290 non-null  object
#  20  year            51290 non-null  int64
# dtypes: float64(3), int64(2), object(16)
# memory usage: 8.2+ MB

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.describe().T
# Out:
#                  count         mean         std       min      25%      50%  \
# quantity       51290.0     3.476545    2.278766     1.000     2.00     3.00
# discount       51290.0     0.142908    0.212280     0.000     0.00     0.00
# profit         51290.0    28.641740  174.424113 -6599.978     0.00     9.24
# shipping_cost  51290.0    26.375915   57.296804     0.000     2.61     7.79
# year           51290.0  2012.777208    1.098931  2011.000  2012.00  2013.00
#
#                    75%       max
# quantity          5.00    14.000
# discount          0.20     0.850
# profit           36.81  8399.976
# shipping_cost    24.45   933.570
# year           2014.00  2014.000

# %%
df.T
# Out:
#                               0                         1      \
# order_id               AG-2011-2040             IN-2011-47883
# order_date                 1/1/2011                  1/1/2011
# ship_date                  1/6/2011                  1/8/2011
# ship_mode            Standard Class            Standard Class
# customer_name       Toby Braunhardt               Joseph Holt
# segment                    Consumer                  Consumer
# state                   Constantine           New South Wales
# country                     Algeria                 Australia
# market                       Africa                      APAC
# region                       Africa                   Oceania
# product_id         OFF-TEN-10000025           OFF-SU-10000618
# category            Office Supplies           Office Supplies
# sub_category                Storage                  Supplies
# product_name    Tenex Lockers, Blue  Acme Trimmer, High Speed
# sales                           408                       120
# quantity                          2                         3
# discount                        0.0                       0.1
# profit                       106.14                    36.036
# shipping_cost                 35.46                      9.72
# order_priority               Medium                    Medium
# year                           2011                      2011
#
#                                   2                            3      \
# order_id                   HU-2011-1220              IT-2011-3647632
# order_date                     1/1/2011                     1/1/2011
# ship_date                      1/5/2011                     1/5/2011
# ship_mode                  Second Class                 Second Class
# customer_name             Annie Thurman                 Eugene Moren
# segment                        Consumer                  Home Office
# state                          Budapest                    Stockholm
# country                         Hungary                       Sweden
# market                             EMEA                           EU
# region                             EMEA                        North
# product_id             OFF-TEN-10001585              OFF-PA-10001492
# category                Office Supplies              Office Supplies
# sub_category                    Storage                        Paper
# product_name    Tenex Box, Single Width  Enermax Note Cards, Premium
# sales                                66                           45
# quantity                              4                            3
# discount                            0.0                          0.5
# profit                            29.64                      -26.055
# shipping_cost                      8.17                         4.82
# order_priority                     High                         High
# year                               2011                         2011
#
#                                      4      \
# order_id                     IN-2011-47883
# order_date                        1/1/2011
# ship_date                         1/8/2011
# ship_mode                   Standard Class
# customer_name                  Joseph Holt
# segment                           Consumer
# state                      New South Wales
# country                          Australia
# market                                APAC
# region                             Oceania
# product_id                 FUR-FU-10003447
# category                         Furniture
# sub_category                   Furnishings
# product_name    Eldon Light Bulb, Duo Pack
# sales                                  114
# quantity                                 5
# discount                               0.1
# profit                               37.77
# shipping_cost                          4.7
# order_priority                      Medium
# year                                  2011
#
#                                                   5      \
# order_id                                  IN-2011-47883
# order_date                                     1/1/2011
# ship_date                                      1/8/2011
# ship_mode                                Standard Class
# customer_name                               Joseph Holt
# segment                                        Consumer
# state                                   New South Wales
# country                                       Australia
# market                                             APAC
# region                                          Oceania
# product_id                              OFF-PA-10001968
# category                                Office Supplies
# sub_category                                      Paper
# product_name    Eaton Computer Printout Paper, 8.5 x 11
# sales                                                55
# quantity                                              2
# discount                                            0.1
# profit                                           15.342
# shipping_cost                                       1.8
# order_priority                                   Medium
# year                                               2011
#
#                                    6                        7      \
# order_id                    CA-2011-1510            IN-2011-79397
# order_date                      1/2/2011                 1/3/2011
# ship_date                       1/6/2011                 1/3/2011
# ship_mode                 Standard Class                 Same Day
# customer_name            Magdelene Morse              Kean Nguyen
# segment                         Consumer                Corporate
# state                            Ontario          New South Wales
# country                           Canada                Australia
# market                            Canada                     APAC
# region                            Canada                  Oceania
# product_id              TEC-OKI-10002750          OFF-AP-10000304
# category                      Technology          Office Supplies
# sub_category                    Machines               Appliances
# product_name    Okidata Inkjet, Wireless  Hoover Microwave, White
# sales                                314                      276
# quantity                               1                        1
# discount                             0.0                      0.1
# profit                              3.12                  110.412
# shipping_cost                       24.1                   125.32
# order_priority                    Medium                 Critical
# year                                2011                     2011
#
#                                       8                                 9      \
# order_id                      ID-2011-80230                      IZ-2011-4680
# order_date                         1/3/2011                          1/3/2011
# ship_date                          1/9/2011                          1/7/2011
# ship_mode                    Standard Class                    Standard Class
# customer_name                  Ken Lonsdale                  Lindsay Williams
# segment                            Consumer                         Corporate
# state                              Auckland                            Ninawa
# country                         New Zealand                              Iraq
# market                                 APAC                              EMEA
# region                              Oceania                              EMEA
# product_id                  TEC-CO-10004182                  FUR-NOV-10002791
# category                         Technology                         Furniture
# sub_category                        Copiers                            Chairs
# product_name    Hewlett Wireless Fax, Laser  Novimex Swivel Stool, Set of Two
# sales                                   912                               667
# quantity                                  4                                 4
# discount                                0.4                               0.0
# profit                             -319.464                            253.32
# shipping_cost                         107.1                             81.26
# order_priority                          Low                              High
# year                                   2011                              2011
#
#                 ...                                           51280  \
# order_id        ...                                    TZ-2014-8220
# order_date      ...                                      12/31/2014
# ship_date       ...                                        1/6/2015
# ship_mode       ...                                  Standard Class
# customer_name   ...                              Christine Kargatis
# segment         ...                                     Home Office
# state           ...                                   Dar Es Salaam
# country         ...                                        Tanzania
# market          ...                                          Africa
# region          ...                                          Africa
# product_id      ...                                OFF-HAR-10001531
# category        ...                                 Office Supplies
# sub_category    ...                                          Labels
# product_name    ...  Harbour Creations Removable Labels, Adjustable
# sales           ...                                              50
# quantity        ...                                               6
# discount        ...                                             0.0
# profit          ...                                            6.84
# shipping_cost   ...                                            2.15
# order_priority  ...                                          Medium
# year            ...                                            2014
#
#                              51281                             51282  \
# order_id            CA-2014-115427                      UP-2014-4410
# order_date              12/31/2014                        12/31/2014
# ship_date                 1/4/2015                          1/4/2015
# ship_mode           Standard Class                    Standard Class
# customer_name           Erica Bern                      Guy Thornton
# segment                  Corporate                          Consumer
# state                   California                      Zaporizhzhya
# country              United States                           Ukraine
# market                          US                              EMEA
# region                        West                              EMEA
# product_id         OFF-BI-10004632                  OFF-AVE-10003558
# category           Office Supplies                   Office Supplies
# sub_category               Binders                            Labels
# product_name    GBC Binding covers  Avery Round Labels, Alphabetical
# sales                           21                                28
# quantity                         2                                 4
# discount                       0.2                               0.0
# profit                       6.475                              6.12
# shipping_cost                 2.06                               1.7
# order_priority              Medium                            Medium
# year                          2014                              2014
#
#                                      51283  \
# order_id                     IN-2014-23754
# order_date                      12/31/2014
# ship_date                         1/7/2015
# ship_mode                   Standard Class
# customer_name                 Kalyca Meade
# segment                          Corporate
# state                            Guangdong
# country                              China
# market                                APAC
# region                          North Asia
# product_id                 OFF-PA-10004727
# category                   Office Supplies
# sub_category                         Paper
# product_name    Eaton Note Cards, 8.5 x 11
# sales                                   79
# quantity                                 3
# discount                               0.0
# profit                               25.38
# shipping_cost                         1.41
# order_priority                      Medium
# year                                  2014
#
#                                                    51284  \
# order_id                                  MX-2014-108574
# order_date                                    12/31/2014
# ship_date                                       1/4/2015
# ship_mode                                 Standard Class
# customer_name                              Julia Barnett
# segment                                      Home Office
# state                                         Tamaulipas
# country                                           Mexico
# market                                             LATAM
# region                                             North
# product_id                               OFF-LA-10004969
# category                                 Office Supplies
# sub_category                                      Labels
# product_name    Novimex Legal Exhibit Labels, Adjustable
# sales                                                 17
# quantity                                               3
# discount                                             0.0
# profit                                              0.66
# shipping_cost                                       1.32
# order_priority                                    Medium
# year                                                2014
#
#                                                           51285  \
# order_id                                         CA-2014-115427
# order_date                                           12/31/2014
# ship_date                                              1/4/2015
# ship_mode                                        Standard Class
# customer_name                                        Erica Bern
# segment                                               Corporate
# state                                                California
# country                                           United States
# market                                                       US
# region                                                     West
# product_id                                      OFF-BI-10002103
# category                                        Office Supplies
# sub_category                                            Binders
# product_name    Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl
# sales                                                        14
# quantity                                                      2
# discount                                                    0.2
# profit                                                   4.5188
# shipping_cost                                              0.89
# order_priority                                           Medium
# year                                                       2014
#
#                                                   51286  \
# order_id                                   MO-2014-2560
# order_date                                   12/31/2014
# ship_date                                      1/5/2015
# ship_mode                                Standard Class
# customer_name                                 Liz Preis
# segment                                        Consumer
# state                                  Souss-Massa-Dra
# country                                         Morocco
# market                                           Africa
# region                                           Africa
# product_id                             OFF-WIL-10001069
# category                                Office Supplies
# sub_category                                    Binders
# product_name    Wilson Jones Hole Reinforcements, Clear
# sales                                                 4
# quantity                                              1
# discount                                            0.0
# profit                                             0.42
# shipping_cost                                      0.49
# order_priority                                   Medium
# year                                               2014
#
#                                                  51287  \
# order_id                                MX-2014-110527
# order_date                                  12/31/2014
# ship_date                                     1/2/2015
# ship_mode                                 Second Class
# customer_name                         Charlotte Melton
# segment                                       Consumer
# state                                          Managua
# country                                      Nicaragua
# market                                           LATAM
# region                                         Central
# product_id                             OFF-LA-10004182
# category                               Office Supplies
# sub_category                                    Labels
# product_name    Hon Color Coded Labels, 5000 Label Set
# sales                                               26
# quantity                                             3
# discount                                           0.0
# profit                                           12.36
# shipping_cost                                     0.35
# order_priority                                  Medium
# year                                              2014
#
#                                                  51288                51289
# order_id                                MX-2014-114783       CA-2014-156720
# order_date                                  12/31/2014           12/31/2014
# ship_date                                     1/6/2015             1/4/2015
# ship_mode                               Standard Class       Standard Class
# customer_name                            Tamara Dahlen        Jill Matthias
# segment                                       Consumer             Consumer
# state                                        Chihuahua             Colorado
# country                                         Mexico        United States
# market                                           LATAM                   US
# region                                           North                 West
# product_id                             OFF-LA-10000413      OFF-FA-10003472
# category                               Office Supplies      Office Supplies
# sub_category                                    Labels            Fasteners
# product_name    Hon Legal Exhibit Labels, Alphabetical  Bagged Rubber Bands
# sales                                                7                    3
# quantity                                             1                    3
# discount                                           0.0                  0.2
# profit                                            0.56              -0.6048
# shipping_cost                                      0.2                 0.17
# order_priority                                  Medium               Medium
# year                                              2014                 2014
#
# [21 rows x 51290 columns]

# %%
df.isnull().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
df.sub_category
# Out:
# 0            Storage
# 1           Supplies
# 2            Storage
# 3              Paper
# 4        Furnishings
#             ...
# 51285        Binders
# 51286        Binders
# 51287         Labels
# 51288         Labels
# 51289      Fasteners
# Name: sub_category, Length: 51290, dtype: object

# %%
df["sub_category"].unique()
# Out:
# array(['Storage', 'Supplies', 'Paper', 'Furnishings', 'Machines',
#        'Appliances', 'Copiers', 'Chairs', 'Tables', 'Bookcases', 'Phones',
#        'Accessories', 'Labels', 'Art', 'Envelopes', 'Fasteners',
#        'Binders'], dtype=object)

# %%
df["sub_category"].value_counts(ascending= True)
# Out:
# sub_category
# Tables          861
# Machines       1486
# Appliances     1755
# Copiers        2223
# Bookcases      2411
# Fasteners      2420
# Supplies       2425
# Envelopes      2435
# Labels         2606
# Accessories    3075
# Furnishings    3170
# Phones         3357
# Chairs         3434
# Paper          3538
# Art            4883
# Storage        5059
# Binders        6152
# Name: count, dtype: int64

# %%
df.groupby("category")["quantity"].sum()
# Out:
# category
# Furniture           34954
# Office Supplies    108182
# Technology          35176
# Name: quantity, dtype: int64

# %%
df.groupby("category")[["quantity", "sales"]].sum()
# Out:
#                  quantity                                              sales
# category
# Furniture           34954  114667211854159691,64838493242,574155262,47998...
# Office Supplies    108182  4081206645552763381231353652628147617186140149...
# Technology          35176  3149121931956922316638283924452743881747562,17...

# %%
df["sales"] = df["sales"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 df["sales"] = df["sales"].astype(int)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:6534, in NDFrame.astype(self, dtype, copy, errors)
#    6530     results = [ser.astype(dtype, copy=copy) for _, ser in self.items()]
#    6532 else:
#    6533     # else, only a single dtype is given
# -> 6534     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6535     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6536     return res.__finalize__(self, method="astype")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:414, in BaseBlockManager.astype(self, dtype, copy, errors)
#     411 elif using_copy_on_write():
#     412     copy = False
# --> 414 return self.apply(
#     415     "astype",
#     416     dtype=dtype,
#     417     copy=copy,
#     418     errors=errors,
#     419     using_cow=using_copy_on_write(),
#     420 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:354, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     352         applied = b.apply(f, **kwargs)
#     353     else:
# --> 354         applied = getattr(b, f)(**kwargs)
#     355     result_blocks = extend_blocks(applied, result_blocks)
#     357 out = type(self).from_blocks(result_blocks, self.axes)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:616, in Block.astype(self, dtype, copy, errors, using_cow)
#     596 """
#     597 Coerce to the new dtype.
#     598
#    (...)
#     612 Block
#     613 """
#     614 values = self.values
# --> 616 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     618 new_values = maybe_coerce_values(new_values)
#     620 refs = None
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:238, in astype_array_safe(values, dtype, copy, errors)
#     235     dtype = dtype.numpy_dtype
#     237 try:
# --> 238     new_values = astype_array(values, dtype, copy=copy)
#     239 except (ValueError, TypeError):
#     240     # e.g. _astype_nansafe can fail on object-dtype of strings
#     241     #  trying to convert to float
#     242     if errors == "ignore":
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~\anaconda3\Lib\site-packages\pandas\core\dtypes\astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# ValueError: invalid literal for int() with base 10: '1,648'

# %%
df["sales"] = df["sales"].replace(",", "", regex=True)

# %%
df["sales"].unique()
# Out:
# array(['408', '120', '66', ..., '1763', '1821', '1831'], dtype=object)

# %%
df["sales"]
# Out:
# 0        408
# 1        120
# 2         66
# 3         45
# 4        114
#         ...
# 51285     14
# 51286      4
# 51287     26
# 51288      7
# 51289      3
# Name: sales, Length: 51290, dtype: object

# %%
df["sales"] = df["sales"].astype(int)

# %%
df.groupby("category")[["quantity", "sales"]].sum()
# Out:
#                  quantity    sales
# category
# Furniture           34954  4110884
# Office Supplies    108182  3787330
# Technology          35176  4744691
